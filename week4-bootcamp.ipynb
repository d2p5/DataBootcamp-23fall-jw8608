# %% [markdown]
# 1. Create a line plot of ZN and INDUS in the housing data.
#
# 	a. For ZN, use a solid green line. For INDUS, use a blue dashed line.
# 	b. Change the figure size to a width of 12 and height of 8.
# 	c. Change the style sheet to something you find https://tonysyu.github.io/raw_content/matplotlib-style-gallery/gallery.html.
#
# 2. Create a bar chart using col1 and col2 of dummy data.
#
# 	a. Give the plot a large title of your choosing.
# 	b. Move the legend to the lower-left corner.
# 	c. Do the same thing but with horizontal bars.
# 	d. Move the legend to the upper-right corner.
#
# 3. Create a histogram with pandas for using MEDV in the housing data.
#
# 	a. Set the bins to 20
#
# 4. Create a scatter plot of two heatmap entries that appear to have a very positive correlation.
#
# 5. Now, create a scatter plot of two heatmap entries that appear to have negative correlation.

# %%
from IPython.display import HTML

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

plt.style.use('fivethirtyeight')
# %matplotlib inline

# %%
housing_csv = 'data/boston_housing_data.csv'
housing = pd.read_csv(housing_csv)
# Out:
# '\n1. Create a line plot of ZN and INDUS in the housing data.\n\n\ta. For ZN, use a solid green line. For INDUS, use a blue dashed line.\n\tb. Change the figure size to a width of 12 and height of 8.\n\tc. Change the style sheet to something you find https://tonysyu.github.io/raw_content/matplotlib-style-gallery/gallery.html.\n\n'

# %%
housing
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273.0
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273.0
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273.0
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273.0
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273.0
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# 2       17.8  392.83   4.03  34.7
# 3       18.7  394.63   2.94  33.4
# 4       18.7  396.90   5.33  36.2
# ..       ...     ...    ...   ...
# 501     21.0  391.99   9.67  22.4
# 502     21.0  396.90   9.08  20.6
# 503     21.0  396.90   5.64  23.9
# 504     21.0  393.45   6.48  22.0
# 505     21.0  396.90   7.88  11.9
#
# [506 rows x 14 columns]

# %%
'''
1. Create a line plot of ZN and INDUS in the housing data.

	a. For ZN, use a solid green line. For INDUS, use a blue dashed line.
	b. Change the figure size to a width of 12 and height of 8.
	c. Change the style sheet to something you find https://tonysyu.github.io/raw_content/matplotlib-style-gallery/gallery.html.

'''
# use ggplot style
plt.style.use('ggplot')
housing[['ZN', 'INDUS']].plot(figsize=(12,8), style={'ZN': 'g-', 'INDUS': 'b--'})
# Out:
# <Axes: >

# %%
'''
2. Create a bar chart using col1 and col2 of dummy data.

	a. Give the plot a large title of your choosing.
	b. Move the legend to the lower-left corner.
	c. Do the same thing but with horizontal bars.
	d. Move the legend to the upper-right corner.
'''

df = pd.DataFrame(np.random.randn(10, 4), 
                  columns=['col1', 'col2', 'col3', 'col4'],
                  index=['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j'])
# Out:
# '\n2. Create a bar chart using col1 and col2 of dummy data.\n\n\ta. Give the plot a large title of your choosing.\n\tb. Move the legend to the lower-left corner.\n\tc. Do the same thing but with horizontal bars.\n\td. Move the legend to the upper-right corner.\n'

# %%
ax = df[['col1', 'col2']].plot(kind='bar', figsize=(12,8))
ax.set_title('bar chart of col1 and col2', fontsize=20)
ax.legend(loc='lower left')

# %%
# horizontal bar chart
ax = df[['col1', 'col2']].plot(kind='barh', figsize=(12,8))
ax.set_title('bar chart of col1 and col2', fontsize=20)
ax.legend(loc='upper right')

# %%
#3. Create a histogram with pandas for using MEDV in the housing data. Set the bins to 20
housing.MEDV.plot(kind='hist', bins=20, figsize=(12,8))
# Out:
# <Axes: ylabel='Frequency'>

# %%
#4. Create a scatter plot of two heatmap entries that appear to have a very positive correlation.
housing_correlations = housing.corr();
sns.heatmap(housing_correlations);

# %%
housing_correlations[(housing_correlations > 0.75) & (housing_correlations < 1)]
# Out:
#              CRIM  ZN     INDUS  CHAS       NOX  RM  AGE  DIS  RAD       TAX  \
# CRIM          NaN NaN       NaN   NaN       NaN NaN  NaN  NaN  NaN  0.793392
# ZN            NaN NaN       NaN   NaN       NaN NaN  NaN  NaN  NaN       NaN
# INDUS         NaN NaN       NaN   NaN  0.763651 NaN  NaN  NaN  NaN       NaN
# CHAS          NaN NaN       NaN   NaN       NaN NaN  NaN  NaN  NaN       NaN
# NOX           NaN NaN  0.763651   NaN       NaN NaN  NaN  NaN  NaN       NaN
# RM            NaN NaN       NaN   NaN       NaN NaN  NaN  NaN  NaN       NaN
# AGE           NaN NaN       NaN   NaN       NaN NaN  NaN  NaN  NaN       NaN
# DIS           NaN NaN       NaN   NaN       NaN NaN  NaN  NaN  NaN       NaN
# RAD           NaN NaN       NaN   NaN       NaN NaN  NaN  NaN  NaN       NaN
# TAX      0.793392 NaN       NaN   NaN       NaN NaN  NaN  NaN  NaN       NaN
# PTRATIO       NaN NaN       NaN   NaN       NaN NaN  NaN  NaN  NaN       NaN
# B             NaN NaN       NaN   NaN       NaN NaN  NaN  NaN  NaN       NaN
# LSTAT         NaN NaN       NaN   NaN       NaN NaN  NaN  NaN  NaN       NaN
# MEDV          NaN NaN       NaN   NaN       NaN NaN  NaN  NaN  NaN       NaN
#
#          PTRATIO   B  LSTAT  MEDV
# CRIM         NaN NaN    NaN   NaN
# ZN           NaN NaN    NaN   NaN
# INDUS        NaN NaN    NaN   NaN
# CHAS         NaN NaN    NaN   NaN
# NOX          NaN NaN    NaN   NaN
# RM           NaN NaN    NaN   NaN
# AGE          NaN NaN    NaN   NaN
# DIS          NaN NaN    NaN   NaN
# RAD          NaN NaN    NaN   NaN
# TAX          NaN NaN    NaN   NaN
# PTRATIO      NaN NaN    NaN   NaN
# B            NaN NaN    NaN   NaN
# LSTAT        NaN NaN    NaN   NaN
# MEDV         NaN NaN    NaN   NaN

# %%
housing.plot(kind='scatter', x='TAX', y='CRIM', figsize=(12,8))
# Out:
# <Axes: xlabel='TAX', ylabel='CRIM'>

# %%
#5. Now, create a scatter plot of two heatmap entries that appear to have negative correlation.
housing_correlations[(housing_correlations < -0.7) & (housing_correlations > -1)]
# Out:
#          CRIM  ZN  INDUS  CHAS       NOX  RM       AGE       DIS  RAD  TAX  \
# CRIM      NaN NaN    NaN   NaN       NaN NaN       NaN       NaN  NaN  NaN
# ZN        NaN NaN    NaN   NaN       NaN NaN       NaN       NaN  NaN  NaN
# INDUS     NaN NaN    NaN   NaN       NaN NaN       NaN       NaN  NaN  NaN
# CHAS      NaN NaN    NaN   NaN       NaN NaN       NaN       NaN  NaN  NaN
# NOX       NaN NaN    NaN   NaN       NaN NaN       NaN -0.748872  NaN  NaN
# RM        NaN NaN    NaN   NaN       NaN NaN       NaN       NaN  NaN  NaN
# AGE       NaN NaN    NaN   NaN       NaN NaN       NaN -0.713313  NaN  NaN
# DIS       NaN NaN    NaN   NaN -0.748872 NaN -0.713313       NaN  NaN  NaN
# RAD       NaN NaN    NaN   NaN       NaN NaN       NaN       NaN  NaN  NaN
# TAX       NaN NaN    NaN   NaN       NaN NaN       NaN       NaN  NaN  NaN
# PTRATIO   NaN NaN    NaN   NaN       NaN NaN       NaN       NaN  NaN  NaN
# B         NaN NaN    NaN   NaN       NaN NaN       NaN       NaN  NaN  NaN
# LSTAT     NaN NaN    NaN   NaN       NaN NaN       NaN       NaN  NaN  NaN
# MEDV      NaN NaN    NaN   NaN       NaN NaN       NaN       NaN  NaN  NaN
#
#          PTRATIO   B     LSTAT      MEDV
# CRIM         NaN NaN       NaN       NaN
# ZN           NaN NaN       NaN       NaN
# INDUS        NaN NaN       NaN       NaN
# CHAS         NaN NaN       NaN       NaN
# NOX          NaN NaN       NaN       NaN
# RM           NaN NaN       NaN       NaN
# AGE          NaN NaN       NaN       NaN
# DIS          NaN NaN       NaN       NaN
# RAD          NaN NaN       NaN       NaN
# TAX          NaN NaN       NaN       NaN
# PTRATIO      NaN NaN       NaN       NaN
# B            NaN NaN       NaN       NaN
# LSTAT        NaN NaN       NaN -0.737663
# MEDV         NaN NaN -0.737663       NaN

# %%
housing.plot(kind='scatter', x='NOX', y='DIS', figsize=(12,8))
# Out:
# <Axes: xlabel='NOX', ylabel='DIS'>
